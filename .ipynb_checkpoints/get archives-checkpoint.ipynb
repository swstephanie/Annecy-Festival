# %%
import requests
from bs4 import BeautifulSoup
import bs4
import pandas as pd
import re
import datetime
from tqdm import tqdm

# %%
def requests_and_check(url):
    response = requests.get(url)
    if not response.status_code == 200:
        print("YES")
    try:
        results_page = BeautifulSoup(response.content,'lxml')
        return results_page
    except:
        print("ERROR")
        return None

def get_archives_info(url = 'https://www.annecy.org/about/archives'):
    results_page = requests_and_check(url)

    df = pd.DataFrame(columns = ['title','year','link'])
    if results_page is None:
        return df
    
    for block in results_page.find_all('div',class_= 'clearfix'):
        year_list = block.find_all('li')
        for year in year_list:
            new_row = {}
            new_row['link'] = year.find('a').get('href').strip()
            title_string = year.find('a').get('title')
            new_row['title'] = re.split(r"\s(?=[0-9])", title_string,maxsplit=1)[0].strip()
            new_row['year'] = re.split(r"\s(?=[0-9])", title_string,maxsplit=1)[1].strip()
            df = df.append(new_row,ignore_index=True)
    return df
get_archives_info()
# Out:
#                      title  year  \
# 0   Check out the archives  2021
# 1   Check out the archives  2020
# 2   Check out the archives  2019
# 3   Check out the archives  2018
# 4   Check out the archives  2017
# ..                     ...   ...
# 93      Official selection  1967
# 94      Official selection  1965
# 95      Official selection  1963
# 96      Official selection  1962
# 97      Official selection  1960
#
#                                                  link
# 0          https://www.annecy.org/about/archives/2021
# 1          https://www.annecy.org/about/archives/2020
# 2          https://www.annecy.org/about/archives/2019
# 3          https://www.annecy.org/about/archives/2018
# 4          https://www.annecy.org/about/archives/2017
# ..                                                ...
# 93  https://www.annecy.org/about/archives/1967/off...
# 94  https://www.annecy.org/about/archives/1965/off...
# 95  https://www.annecy.org/about/archives/1963/off...
# 96  https://www.annecy.org/about/archives/1962/off...
# 97  https://www.annecy.org/about/archives/1960/off...
#
# [98 rows x 3 columns]

# %%
def get_official_selection_df_year(
    year_url = 'https://www.annecy.org/about/archives/2021/official-selection',\
    year = '2021'):
    title = 'Official selection'
    results_page = requests_and_check(year_url)
    df = pd.DataFrame(columns = ['title','year','selection','link'])
    
    if results_page is None:
        return df
    
    for i in results_page.find('div',class_='grd-cat__list').find_all('a'):
        new_row = {}
        new_row['selection'] = i.get_text().strip()
        new_row['link'] = i.get('href').strip()
        df = df.append(new_row,ignore_index=True)
    df.title = title
    df.year = year
    return df
get_official_selection_df_year()
# Out:
#                  title  year                    selection  \
# 0   Official selection  2021       Official Feature Films
# 1   Official selection  2021    Feature Films Contrechamp
# 2   Official selection  2021         Official Short Films
# 3   Official selection  2021       Off-Limits Short Films
# 4   Official selection  2021     Perspectives Short Films
# 5   Official selection  2021  Young Audiences Short Films
# 6   Official selection  2021       Graduation Short Films
# 7   Official selection  2021                     TV Films
# 8   Official selection  2021           Commissioned Films
# 9   Official selection  2021                     VR Works
# 10  Official selection  2021             Work in Progress
# 11  Official selection  2021             Screening Events
#
#                                                  link
# 0   https://www.annecy.org/about/archives/2021/off...
# 1   https://www.annecy.org/about/archives/2021/off...
# 2   https://www.annecy.org/about/archives/2021/off...
# 3   https://www.annecy.org/about/archives/2021/off...
# 4   https://www.annecy.org/about/archives/2021/off...
# 5   https://www.annecy.org/about/archives/2021/off...
# 6   https://www.annecy.org/about/archives/2021/off...
# 7   https://www.annecy.org/about/archives/2021/off...
# 8   https://www.annecy.org/about/archives/2021/off...
# 9   https://www.annecy.org/about/archives/2021/off...
# 10  https://www.annecy.org/about/archives/2021/off...
# 11  https://www.annecy.org/about/archives/2021/off...

# %%
def get_awards_df_year(year_url = 'https://www.annecy.org/about/archives/2021/award-winners',\
                      year = '2021'):
    
    title = 'Awards'
    results_page = requests_and_check(year_url)
    df = pd.DataFrame(columns = ['title','year','department','award','film','img_link','film_link'])
    if results_page is None:
        return df
    
    if int(year) >= 2011:
        ls = []
        for i in results_page.find('div',{'id':'palmares'}):
            if type(i) == bs4.element.Tag:
                ls.append(i)
        for i, j in zip(ls[0::2],ls[1::2]):
            department = i.get_text().strip()
            for item in j.find_all('li'):
                item_dict = {}
                item_dict['department'] = department
                item_dict['award'] = item.find('h2').get_text()
                item_dict['film'] = item.find('h4').get_text()
                item_dict['img_link'] = item.find('img').get('src')
                item_dict['film_link'] = item.find('a').get('href')

                df = df.append(item_dict,ignore_index=True)
    else:
        depts = results_page.find('div',class_= 'blc p_com').find_all('div',class_="palm_categ")
        dept_films = results_page.find('div',class_= 'blc p_com').find_all('ul')

        for dept, films in zip(depts,dept_films):
            department = dept.get_text().strip()
            for film in films.find_all('li'):
                item_dict = {}
                item_dict['department'] = department
                item_dict['award'] = film.find('h6').get_text()
                item_dict['film'] = film.find('h3').get_text()
                item_dict['img_link'] = film.find('img').get('src')
                item_dict['film_link'] = film.find('a').get('href')
                
                df = df.append(item_dict,ignore_index=True)
            
    
    df.year = year
    df.title = title
    return df

def get_award_df():
    df = get_archives_info()
    df = df[df.title == 'Découvrez le Palmarés']
    years = df.year.tolist()
    year_urls = df.link.tolist()
    output = pd.DataFrame(columns = ['title','year','department','award','film','img_link','film_link'])
    for year, year_url in zip(years,year_urls): 
        output = pd.concat([output, get_awards_df_year(year_url=year_url,year=year)],ignore_index = True)
    return output
get_award_df()
# Out:
#       title  year                      department  \
# 0    Awards  2021                   Feature films
# 1    Awards  2021                   Feature films
# 2    Awards  2021                   Feature films
# 3    Awards  2021                   Feature films
# 4    Awards  2021                   Feature films
# ..      ...   ...                             ...
# 860  Awards  1960                     Short films
# 861  Awards  1960                     Short films
# 862  Awards  1960                     Short films
# 863  Awards  1960  Short Films out of Competition
# 864  Awards  1960              Commissioned Films
#
#                                                  award  \
# 0                           Cristal for a Feature Film
# 1                                           Jury Award
# 2                                     Jury Distinction
# 3                Gan Foundation Award for Distribution
# 4                                    Contrechamp Award
# ..                                                 ...
# 860  Award for its humanitarian theme and graphical...
# 861                     Award for aesthetic research\n
# 862                 Award for poetry and popular art\n
# 863                     International Critics' Award\n
# 864                            Very short film Award\n
#
#                                        film  \
# 0                                      Flee
# 1                        Ma famille afghane
# 2                              La Traversée
# 3                                      Flee
# 4     Bob Cuspe - Nós Não Gostamos de Gente
# ..                                      ...
# 860                                  Pozor!
# 861  Prélude pour voix, orchestre et caméra
# 862                      Vlyublennoe oblako
# 863                                Moonbird
# 864     Necchi : Machine à coudre : Zig-zag
#
#                                               img_link  \
# 0    https://www.annecy.org/resources/images/m/2021...
# 1    https://www.annecy.org/resources/images/m/2021...
# 2    https://www.annecy.org/resources/images/m/2021...
# 3    https://www.annecy.org/resources/images/m/2021...
# 4    https://www.annecy.org/resources/images/m/2021...
# ..                                                 ...
# 860  https://www.annecy.org/resources/images/t/6010...
# 861  https://www.annecy.org/resources/images/t/defa...
# 862  https://www.annecy.org/resources/images/t/defa...
# 863  https://www.annecy.org/resources/images/t/6000...
# 864  https://www.annecy.org/resources/images/t/6000...
#
#                                              film_link
# 0    https://www.annecy.org/about/archives/2021/awa...
# 1    https://www.annecy.org/about/archives/2021/awa...
# 2    https://www.annecy.org/about/archives/2021/awa...
# 3    https://www.annecy.org/about/archives/2021/awa...
# 4    https://www.annecy.org/about/archives/2021/awa...
# ..                                                 ...
# 860  https://www.annecy.org/about/archives/1960/awa...
# 861  https://www.annecy.org/about/archives/1960/awa...
# 862  https://www.annecy.org/about/archives/1960/awa...
# 863  https://www.annecy.org/about/archives/1960/awa...
# 864  https://www.annecy.org/about/archives/1960/awa...
#
# [865 rows x 7 columns]

# %%
def get_film_info(url='https://www.annecy.org/about/archives/2021/official-selection/film-index:film-20211299'):
    results_page = requests_and_check(url)
    if results_page is None:
        return pd.DataFrame()
    new_dict = {}

    results = results_page.find("div", class_='blc_identite').find_all('div', class_="sous-blc_content")

    for i in range(len(results)):
        for j in results[i].find_all('p'):
            lt = j.get_text().split(":", 1)
            ###TEST
            try:
                new_dict[lt[0].strip()] = lt[1].strip()
            except:
                continue
    try:
        new_dict['Overview'] = results_page.find('div', class_='accroche').get_text().strip()
    except:
        new_dict['Overview'] = ''
    if 'df' not in locals():
        df = pd.DataFrame(new_dict, index=[0])
    else:
        df = df.append(new_dict, ignore_index=True)
    return df


get_film_info()
# Out:
#        Original title   Directed by                 Country  \
# 0  Affairs of the Art  Joanna QUINN  United Kingdom, Canada
#
#   Year of production Running time    Category   Techniques used  \
# 0               2021       16 min  Short film  drawing on paper
#
#                                      Version Process  \
# 0  Original English version French subtitles  Colour
#
#                  Target public  \
# 0  Teens, Adults, Young adults
#
#                                           Production  \
# 0  BERYL PRODUCTIONS INTERNATIONAL LTD., Les MILL...
#
#                                         Distribution     Script  \
# 0  ONF - OFFICE NATIONAL DU FILM DU CANADA, Élise...  Les Mills
#
#                      Animation                     Compositing  \
# 0  Joanna Quinn, James Nutting  Mia Rose Goddard, Fran Breslin
#
#               Music           Editing  \
# 0  Benjamin Talbott  Mia Rose Goddard
#
#                                                Voice  \
# 0  Menna Trussler, Brendan Charleson, Joanna Quin...
#
#                                             Overview
# 0  Beryl's back in "Affairs of the Art", which sh...

# %%
def get_dept_in_official_selection_year(year, url):
    df = pd.DataFrame(columns = ['year'])
    results_page = requests_and_check(url)
    for dept in results_page.find('div',class_= 'grd-cat__item').find_all('a'):
        department = dept.get_text().strip()
        dept_url = dept.get('href')
        dept_page = requests_and_check(dept_url)
        if dept_page.find('ul',class_='liste_films') is None:
            continue
        for film in dept_page.find('ul',class_='liste_films').find_all('li'):
            film_url = film.find('a').get('href')
            film_df = get_film_info(film_url)
            #test
            if film_df is None:
                return "YES"
            film_df['department'] = department
            df = pd.concat([df,film_df],ignore_index= True)

    df.year = year
    return df

# %%
# %%time
for i in df[df.title=='Official selection'].link.tolist():
    try:
        get_dept_in_official_selection_year(year = 'test',url = i)
        print(i)
        break
    except:
        print("ERROR!!!!!!!!!!!!!!!!!")
        print(i)
        break
# Out:
# https://www.annecy.org/about/archives/2021/official-selection
# CPU times: user 22.3 s, sys: 826 ms, total: 23.1 s
# Wall time: 3min 59s

# %%
# %%time
for i in df[df.title=='Official selection'].link.tolist():
    try:
        get_dept_in_official_selection_year(year = 'test',url = i)
        print(i)
    except:
        print("ERROR!!!!!!!!!!!!!!!!!")
        print(i)
        break
# Out:
# https://www.annecy.org/about/archives/2021/official-selection
# https://www.annecy.org/about/archives/2020/official-selection
# https://www.annecy.org/about/archives/2019/official-selection
# https://www.annecy.org/about/archives/2018/official-selection
# https://www.annecy.org/about/archives/2017/official-selection
# https://www.annecy.org/about/archives/2016/official-selection
# https://www.annecy.org/about/archives/2015/official-selection
# https://www.annecy.org/about/archives/2014/official-selection
# https://www.annecy.org/about/archives/2013/official-selection
# https://www.annecy.org/about/archives/2012/official-selection
# https://www.annecy.org/about/archives/2011/official-selection
# https://www.annecy.org/about/archives/2010/official-selection
# https://www.annecy.org/about/archives/2009/official-selection
# https://www.annecy.org/about/archives/2008/official-selection
# https://www.annecy.org/about/archives/2007/official-selection
# https://www.annecy.org/about/archives/2006/official-selection
# https://www.annecy.org/about/archives/2005/official-selection
# https://www.annecy.org/about/archives/2004/official-selection
# https://www.annecy.org/about/archives/2003/official-selection
# https://www.annecy.org/about/archives/2002/official-selection
# https://www.annecy.org/about/archives/2001/official-selection
# https://www.annecy.org/about/archives/2000/official-selection
# https://www.annecy.org/about/archives/1999/official-selection
# https://www.annecy.org/about/archives/1998/official-selection
# https://www.annecy.org/about/archives/1997/official-selection
# https://www.annecy.org/about/archives/1995/official-selection
# https://www.annecy.org/about/archives/1993/official-selection
# https://www.annecy.org/about/archives/1991/official-selection
# https://www.annecy.org/about/archives/1989/official-selection
# https://www.annecy.org/about/archives/1987/official-selection
# https://www.annecy.org/about/archives/1985/official-selection
# https://www.annecy.org/about/archives/1983/official-selection
# https://www.annecy.org/about/archives/1981/official-selection
# https://www.annecy.org/about/archives/1979/official-selection
# https://www.annecy.org/about/archives/1977/official-selection
# https://www.annecy.org/about/archives/1975/official-selection
# https://www.annecy.org/about/archives/1973/official-selection
# https://www.annecy.org/about/archives/1971/official-selection
# https://www.annecy.org/about/archives/1967/official-selection
# https://www.annecy.org/about/archives/1965/official-selection
# https://www.annecy.org/about/archives/1963/official-selection
# https://www.annecy.org/about/archives/1962/official-selection
# https://www.annecy.org/about/archives/1960/official-selection
# CPU times: user 9min 18s, sys: 26.3 s, total: 9min 45s
# Wall time: 1h 50min 18s
